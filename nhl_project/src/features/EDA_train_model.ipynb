# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import missingno

from catboost import CatBoostClassifier
from sklearn.metrics import precision_score, recall_score

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix, classification_report

# %%
PROCESSED_PATH = "/Users/shiryaevva/HSE/2-nd_year/nhl-ml-project/nhl_project/data/processed/"
REPORTING_PATH = "/Users/shiryaevva/HSE/2-nd_year/nhl-ml-project/nhl_project/data/dwh/vault/reporting/"

# %%
teams_stat = pd.read_csv(REPORTING_PATH + 'teams_statistics.csv')
teams_stat.head()
# Out:
#          date  season_id team_business_id  conference_home_sequence  \
# 0  2012-01-01   20112012              BOS                         2
# 1  2012-01-01   20112012              PHX                        13
# 2  2012-01-01   20112012              VAN                         9
# 3  2012-01-01   20112012              TBL                         8
# 4  2012-01-01   20112012              TOR                        11
#
#    conference_l10_sequence  conference_road_sequence  conference_sequence  \
# 0                        1                         2                    2
# 1                       11                         2                   11
# 2                        5                         1                    2
# 3                        7                        12                   12
# 4                       12                         7                   10
#
#    division_home_sequence  division_l10_sequence  division_road_sequence  ...  \
# 0                       1                      1                       1  ...
# 1                       4                      4                       1  ...
# 2                       3                      2                       1  ...
# 3                       4                      3                       3  ...
# 4                       4                      3                       2  ...
#
#    win_pctg  wins  _source_load_datetime  _source_is_deleted  _source  \
# 0  0.685714    24    2012-01-01 00:00:00               False  API_NHL
# 1  0.487179    19    2012-01-01 00:00:00               False  API_NHL
# 2  0.615385    24    2012-01-01 00:00:00               False  API_NHL
# 3  0.459459    17    2012-01-01 00:00:00               False  API_NHL
# 4  0.473684    18    2012-01-01 00:00:00               False  API_NHL
#
#     _batch_id                                   team_id  team_source_id  \
# 0  2024-03-24  0bd9564a48ab0de04df8e876d1a1de3c6d4e30f2               6
# 1  2024-03-24  1ce51de9db580729e7833191b1d0daf6600f801e              27
# 2  2024-03-24  294224f05292070f79b3a86048602d3fc2ef129e              23
# 3  2024-03-24  384c73fcd755def9f5750f2ab52fceb3165b718a              14
# 4  2024-03-24  430e84f2b6d2c4f1dd22d50047f1fe24dc05c263              10
#
#    conference_name  division_name
# 0          Eastern       Atlantic
# 1          Western        Pacific
# 2          Western        Pacific
# 3          Eastern       Atlantic
# 4          Eastern       Atlantic
#
# [5 rows x 80 columns]

# %%
df_games = pd.read_csv(PROCESSED_PATH + 'games_statistics_wide.csv').sort_values(by='game_date')
df_games.head()
# Out:
#    game_source_id   game_date    season home_team_code visiting_team_code  \
# 0      2011020572  2012-01-02  20112012            VAN                SJS
# 1      2011020571  2012-01-02  20112012            CHI                EDM
# 2      2011020570  2012-01-02  20112012            OTT                NJD
# 3      2011020573  2012-01-02  20112012            LAK                COL
# 4      2011020569  2012-01-02  20112012            PHI                NYR
#
#    game_type  home_score  visiting_score  score_delta  \
# 0          2           2               3           -1
# 1          2           3               4           -1
# 2          2           3               2            1
# 3          2           1               2           -1
# 4          2           2               3           -1
#
#    h_conference_home_sequence  ...  v_streak_count  v_ties  \
# 0                           9  ...               1       0
# 1                           4  ...               3       0
# 2                           7  ...               2       0
# 3                          10  ...               2       0
# 4                          14  ...               1       0
#
#    v_waivers_sequence  v_wildcard_sequence  v_win_pctg  v_wins  \
# 0                  23                    0    0.558824      19
# 1                   5                    0    0.405405      15
# 2                  17                    0    0.567568      21
# 3                  10                    0    0.525000      21
# 4                  29                    0    0.638889      23
#
#    v_conference_name  v_division_name  home_team_winner  game_month
# 0            Western          Pacific                 0           1
# 1            Western          Pacific                 0           1
# 2            Eastern     Metropolitan                 1           1
# 3            Western          Central                 0           1
# 4            Eastern     Metropolitan                 0           1
#
# [5 rows x 153 columns]

# %%
missingno.matrix(df_games, figsize=(20, 7), label_rotation=45, fontsize=10);

# %%
df_games.dropna(inplace=True)

# %%
plt.figure(figsize=(20, 7))

plt.subplot(1, 2, 1)
sns.histplot(data=df_games, x='home_score', bins=10, color='blue', label='Home Team')
sns.histplot(data=df_games, x='visiting_score', bins=10, color='red', label='Visiting Team')
plt.title('Distribution of Scores', fontsize=16)
plt.xlabel('Score', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.legend()


plt.subplot(1, 2, 2)
ax = sns.countplot(data=df_games, x='home_team_winner')

for rect in ax.patches:
    ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 100, 
            rect.get_height(), horizontalalignment='center', fontsize = 10)
    
plt.title('Distribution of Home Team Winners', fontsize=16)
plt.xlabel('Home Team Winner', fontsize=13)
plt.ylabel('Count', fontsize=13)

plt.tight_layout()
plt.show()

# %%
all_dates = teams_stat[(teams_stat.season_id >= 20222023)]['date'].unique()
selected_dates = all_dates[::5]

plt.figure(figsize=(30, 10))
sns.lineplot(data=teams_stat[(teams_stat.season_id >= 20222023)], hue='team_business_id', x='date', y='win_pctg', color='red')

plt.title('Team win percantage for last two seasons', fontsize=20)
plt.xlabel('Game Date', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.xticks(selected_dates, rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ## Разделим данные на train и test

# %%
df_games = df_games.sort_values(by='game_date')

test_index = int(0.2 * len(df_games))

df_train = df_games.iloc[:-test_index]
df_test = df_games.iloc[-test_index:]

# %%
X_train = df_train.drop(columns=["game_source_id",
                                 "game_date",
                                 "game_type",
                                 "score_delta",
                                 "home_team_winner",
                                 "home_score",
                                 "visiting_score",])
y_train = df_train.home_team_winner

X_test = df_test.drop(columns=["game_source_id",
                               "game_date",
                                "game_type",
                                "score_delta",
                                "home_team_winner",
                                "home_score",
                                "visiting_score",])

y_test = df_test.home_team_winner

X_train.head()
# Out:
#      season home_team_code visiting_team_code  h_conference_home_sequence  \
# 0  20112012            VAN                SJS                           9
# 1  20112012            CHI                EDM                           4
# 2  20112012            OTT                NJD                           7
# 3  20112012            LAK                COL                          10
# 4  20112012            PHI                NYR                          14
#
#    h_conference_l10_sequence  h_conference_road_sequence  \
# 0                          5                           1
# 1                          1                           3
# 2                          8                           8
# 3                          3                           5
# 4                          5                           1
#
#    h_conference_sequence  h_division_home_sequence  h_division_l10_sequence  \
# 0                      2                         3                        2
# 1                      1                         2                        1
# 2                      8                         2                        2
# 3                      3                         3                        1
# 4                      4                         5                        3
#
#    h_division_road_sequence  ...  v_streak_code  v_streak_count  v_ties  \
# 0                         1  ...             OT               1       0
# 1                         1  ...              L               3       0
# 2                         3  ...              W               2       0
# 3                         2  ...              W               2       0
# 4                         1  ...              W               1       0
#
#    v_waivers_sequence  v_wildcard_sequence  v_win_pctg  v_wins  \
# 0                  23                    0    0.558824      19
# 1                   5                    0    0.405405      15
# 2                  17                    0    0.567568      21
# 3                  10                    0    0.525000      21
# 4                  29                    0    0.638889      23
#
#    v_conference_name  v_division_name  game_month
# 0            Western          Pacific           1
# 1            Western          Pacific           1
# 2            Eastern     Metropolitan           1
# 3            Western          Central           1
# 4            Eastern     Metropolitan           1
#
# [5 rows x 146 columns]

# %% [markdown]
# ## Обучим модель предсказывать какая команды победит - домашняя 1, на выезде 0

# %%
categorical_features = [
    "season",
    "home_team_code",
    "visiting_team_code",
    "h_conference_name",
    "h_division_name",
    "h_streak_code",
    "v_conference_name",
    "v_division_name",
    "v_streak_code",
    "game_month"
]

# %%
catboost_cl = CatBoostClassifier(
                          iterations=10000,
                          random_state=17,
                          cat_features=categorical_features,
                          verbose=100)

catboost_cl.fit(X_train, y_train, verbose=100)

y_pred = catboost_cl.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# Learning rate set to 0.003539
# 0:	learn: 0.6930420	total: 33.4ms	remaining: 5m 34s
# 100:	learn: 0.6841740	total: 1.33s	remaining: 2m 10s
# 200:	learn: 0.6784854	total: 2.76s	remaining: 2m 14s
# 300:	learn: 0.6744875	total: 3.99s	remaining: 2m 8s
# 400:	learn: 0.6714276	total: 5.63s	remaining: 2m 14s
# 500:	learn: 0.6687875	total: 6.89s	remaining: 2m 10s
# 600:	learn: 0.6663784	total: 8.36s	remaining: 2m 10s
# 700:	learn: 0.6642231	total: 9.77s	remaining: 2m 9s
# 800:	learn: 0.6622715	total: 11.2s	remaining: 2m 9s
# 900:	learn: 0.6604457	total: 12.6s	remaining: 2m 7s
# 1000:	learn: 0.6587538	total: 13.9s	remaining: 2m 4s
# 1100:	learn: 0.6570906	total: 15.3s	remaining: 2m 3s
# 1200:	learn: 0.6554410	total: 16.6s	remaining: 2m 1s
# 1300:	learn: 0.6538655	total: 18.2s	remaining: 2m 1s
# 1400:	learn: 0.6523467	total: 19.6s	remaining: 2m
# 1500:	learn: 0.6508499	total: 20.8s	remaining: 1m 58s
# 1600:	learn: 0.6493858	total: 22.1s	remaining: 1m 55s
# 1700:	learn: 0.6478666	total: 23.5s	remaining: 1m 54s
# 1800:	learn: 0.6464750	total: 24.7s	remaining: 1m 52s
# 1900:	learn: 0.6450071	total: 25.9s	remaining: 1m 50s
# 2000:	learn: 0.6435375	total: 27.4s	remaining: 1m 49s
# 2100:	learn: 0.6420810	total: 28.9s	remaining: 1m 48s
# 2200:	learn: 0.6407051	total: 30.2s	remaining: 1m 47s
# 2300:	learn: 0.6392746	total: 31.5s	remaining: 1m 45s
# 2400:	learn: 0.6377491	total: 33s	remaining: 1m 44s
# 2500:	learn: 0.6362590	total: 34.2s	remaining: 1m 42s
# 2600:	learn: 0.6346834	total: 35.6s	remaining: 1m 41s
# 2700:	learn: 0.6330590	total: 37s	remaining: 1m 39s
# 2800:	learn: 0.6314163	total: 38.2s	remaining: 1m 38s
# 2900:	learn: 0.6296412	total: 39.7s	remaining: 1m 37s
# 3000:	learn: 0.6278166	total: 40.9s	remaining: 1m 35s
# 3100:	learn: 0.6259624	total: 42.4s	remaining: 1m 34s
# 3200:	learn: 0.6239387	total: 43.7s	remaining: 1m 32s
# 3300:	learn: 0.6220562	total: 45.1s	remaining: 1m 31s
# 3400:	learn: 0.6199007	total: 46.6s	remaining: 1m 30s
# 3500:	learn: 0.6179968	total: 47.9s	remaining: 1m 28s
# 3600:	learn: 0.6160040	total: 49.2s	remaining: 1m 27s
# 3700:	learn: 0.6139042	total: 50.7s	remaining: 1m 26s
# 3800:	learn: 0.6119814	total: 52.1s	remaining: 1m 24s
# 3900:	learn: 0.6099340	total: 53.3s	remaining: 1m 23s
# 4000:	learn: 0.6078097	total: 54.8s	remaining: 1m 22s
# 4100:	learn: 0.6058686	total: 56s	remaining: 1m 20s
# 4200:	learn: 0.6040348	total: 57.3s	remaining: 1m 19s
# 4300:	learn: 0.6022265	total: 58.7s	remaining: 1m 17s
# 4400:	learn: 0.6003690	total: 60s	remaining: 1m 16s
# 4500:	learn: 0.5984981	total: 1m 1s	remaining: 1m 14s
# 4600:	learn: 0.5966554	total: 1m 3s	remaining: 1m 14s
# 4700:	learn: 0.5948962	total: 1m 4s	remaining: 1m 12s
# 4800:	learn: 0.5928979	total: 1m 5s	remaining: 1m 11s
# 4900:	learn: 0.5909500	total: 1m 7s	remaining: 1m 9s
# 5000:	learn: 0.5891802	total: 1m 8s	remaining: 1m 8s
# 5100:	learn: 0.5874026	total: 1m 9s	remaining: 1m 7s
# 5200:	learn: 0.5856500	total: 1m 11s	remaining: 1m 5s
# 5300:	learn: 0.5836512	total: 1m 12s	remaining: 1m 4s
# 5400:	learn: 0.5818681	total: 1m 13s	remaining: 1m 2s
# 5500:	learn: 0.5799893	total: 1m 15s	remaining: 1m 1s
# 5600:	learn: 0.5781147	total: 1m 16s	remaining: 1m
# 5700:	learn: 0.5765350	total: 1m 17s	remaining: 58.7s
# 5800:	learn: 0.5747433	total: 1m 19s	remaining: 57.4s
# 5900:	learn: 0.5731367	total: 1m 20s	remaining: 55.9s
# 6000:	learn: 0.5715529	total: 1m 21s	remaining: 54.6s
# 6100:	learn: 0.5698901	total: 1m 23s	remaining: 53.2s
# 6200:	learn: 0.5682443	total: 1m 24s	remaining: 51.8s
# 6300:	learn: 0.5666533	total: 1m 25s	remaining: 50.5s
# 6400:	learn: 0.5649757	total: 1m 27s	remaining: 49.1s
# 6500:	learn: 0.5633248	total: 1m 28s	remaining: 47.7s
# 6600:	learn: 0.5616837	total: 1m 29s	remaining: 46.3s
# 6700:	learn: 0.5600839	total: 1m 31s	remaining: 44.9s
# 6800:	learn: 0.5584106	total: 1m 32s	remaining: 43.6s
# 6900:	learn: 0.5569310	total: 1m 33s	remaining: 42.2s
# 7000:	learn: 0.5555061	total: 1m 35s	remaining: 40.8s
# 7100:	learn: 0.5540038	total: 1m 36s	remaining: 39.5s
# 7200:	learn: 0.5524874	total: 1m 37s	remaining: 38.1s
# 7300:	learn: 0.5510155	total: 1m 39s	remaining: 36.7s
# 7400:	learn: 0.5493835	total: 1m 40s	remaining: 35.3s
# 7500:	learn: 0.5479549	total: 1m 41s	remaining: 33.9s
# 7600:	learn: 0.5465236	total: 1m 43s	remaining: 32.6s
# 7700:	learn: 0.5450137	total: 1m 44s	remaining: 31.2s
# 7800:	learn: 0.5434796	total: 1m 45s	remaining: 29.8s
# 7900:	learn: 0.5419761	total: 1m 47s	remaining: 28.5s
# 8000:	learn: 0.5404915	total: 1m 48s	remaining: 27.1s
# 8100:	learn: 0.5388993	total: 1m 49s	remaining: 25.8s
# 8200:	learn: 0.5374766	total: 1m 51s	remaining: 24.4s
# 8300:	learn: 0.5358874	total: 1m 52s	remaining: 23s
# 8400:	learn: 0.5345338	total: 1m 54s	remaining: 21.7s
# 8500:	learn: 0.5330938	total: 1m 55s	remaining: 20.3s
# 8600:	learn: 0.5316515	total: 1m 56s	remaining: 19s
# 8700:	learn: 0.5302374	total: 1m 57s	remaining: 17.6s
# 8800:	learn: 0.5287577	total: 1m 59s	remaining: 16.2s
# 8900:	learn: 0.5272259	total: 2m	remaining: 14.9s
# 9000:	learn: 0.5257423	total: 2m 1s	remaining: 13.5s
# 9100:	learn: 0.5243408	total: 2m 3s	remaining: 12.2s
# 9200:	learn: 0.5228819	total: 2m 4s	remaining: 10.8s
# 9300:	learn: 0.5215632	total: 2m 5s	remaining: 9.45s
# 9400:	learn: 0.5200049	total: 2m 6s	remaining: 8.09s
# 9500:	learn: 0.5186560	total: 2m 8s	remaining: 6.74s
# 9600:	learn: 0.5171983	total: 2m 9s	remaining: 5.39s
# 9700:	learn: 0.5159631	total: 2m 10s	remaining: 4.03s
# 9800:	learn: 0.5146881	total: 2m 12s	remaining: 2.68s
# 9900:	learn: 0.5132697	total: 2m 13s	remaining: 1.33s
# 9999:	learn: 0.5118081	total: 2m 14s	remaining: 0us
# Precision: 0.5617408906882592
# Recall: 0.7231270358306189

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.35      0.42      1340
#            1       0.56      0.72      0.63      1535
#
#     accuracy                           0.55      2875
#    macro avg       0.54      0.54      0.53      2875
# weighted avg       0.55      0.55      0.53      2875

# %%
def plot_feature_importance(model, X):
    model_importances = pd.DataFrame(model.feature_importances_, columns=['feature_importance'], index=X.columns)
    
    fig = plt.figure(figsize = (20, 30))
    sns.set_style('white')
    ax = sns.barplot(x='feature_importance', 
                y=model_importances.index, 
                data=model_importances, 
                order=model_importances.sort_values(by='feature_importance', ascending=False).index);

    for rect in ax.patches:
        ax.text(rect.get_width() + 0.001, rect.get_y() + rect.get_height() / 2, 
                round(rect.get_width(), 3), verticalalignment='center', fontsize = 11)

    plt.xlabel('Feature importance', fontsize=16);
    plt.ylabel('Feature', fontsize=16);
    
    return model_importances

# %%
catboost_cl_importance = plot_feature_importance(catboost_cl, X_train)

# %% [markdown]
# ### Оставим первые 100 фичей

# %%
top_100_features = list(catboost_cl_importance.sort_values(by='feature_importance', ascending=False).reset_index().rename(columns={'index': 'feature'}).feature)[:100]

# %%
X_train_100 = X_train[top_100_features]
X_test_100 = X_test[top_100_features]

X_train_100.head()
# Out:
#   home_team_code  v_goals_for_pctg  h_goals_for_pctg  h_regulation_win_pctg  \
# 0            VAN          2.911765          3.307692               0.512821
# 1            CHI          2.702703          3.289474               0.447368
# 2            OTT          2.783784          3.076923               0.307692
# 3            LAK          2.700000          2.205128               0.358974
# 4            PHI          2.972222          3.416667               0.527778
#
#   visiting_team_code  h_l10_goals_for h_streak_code    season  \
# 0                SJS               32             L  20112012
# 1                EDM               32             W  20112012
# 2                NJD               30             W  20112012
# 3                COL               21             W  20112012
# 4                NYR               30             W  20112012
#
#    v_regulation_win_pctg  v_l10_goals_for  ...  h_l10_regulation_wins  \
# 0               0.411765               31  ...                      5
# 1               0.378378               24  ...                      5
# 2               0.297297               33  ...                      2
# 3               0.300000               30  ...                      4
# 4               0.583333               30  ...                      6
#
#    v_conference_l10_sequence  h_home_ot_losses h_road_regulation_plus_ot_wins  \
# 0                          6                 1                             12
# 1                         15                 3                              8
# 2                          4                 1                              5
# 3                          2                 1                              7
# 4                          2                 2                             14
#
#    h_conference_road_sequence  h_losses  v_home_losses  h_home_points  \
# 0                           1        13              7             23
# 1                           3        10              6             31
# 2                           8        15              6             23
# 3                           5        14             10             23
# 4                           1        10              3             18
#
#    h_l10_points  v_l10_ot_losses
# 0            13                3
# 1            16                0
# 2            13                0
# 3            14                0
# 4            13                0
#
# [5 rows x 100 columns]

# %%
categorical_features = [
    "season",
    "home_team_code",
    "visiting_team_code",
    # "h_conference_name",
    "h_division_name",
    "h_streak_code",
    # "v_conference_name",
    "v_division_name",
    "v_streak_code"
]

# %%
catboost_cl_top_100 = CatBoostClassifier(
                          iterations=10000,
                          random_state=17,
                          cat_features=categorical_features,
                          verbose=100)

catboost_cl_top_100.fit(X_train_100, y_train, verbose=100)

y_pred = catboost_cl_top_100.predict(X_test_100)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# Learning rate set to 0.003539
# 0:	learn: 0.6930228	total: 21.2ms	remaining: 3m 32s
# 100:	learn: 0.6840328	total: 1.16s	remaining: 1m 53s
# 200:	learn: 0.6782512	total: 2.57s	remaining: 2m 5s
# 300:	learn: 0.6742653	total: 3.66s	remaining: 1m 57s
# 400:	learn: 0.6711547	total: 4.95s	remaining: 1m 58s
# 500:	learn: 0.6684347	total: 6.06s	remaining: 1m 54s
# 600:	learn: 0.6662767	total: 7.33s	remaining: 1m 54s
# 700:	learn: 0.6640777	total: 8.46s	remaining: 1m 52s
# 800:	learn: 0.6621847	total: 9.76s	remaining: 1m 52s
# 900:	learn: 0.6603317	total: 10.9s	remaining: 1m 49s
# 1000:	learn: 0.6585933	total: 12.1s	remaining: 1m 48s
# 1100:	learn: 0.6569033	total: 13.3s	remaining: 1m 47s
# 1200:	learn: 0.6553310	total: 14.6s	remaining: 1m 46s
# 1300:	learn: 0.6537525	total: 15.7s	remaining: 1m 44s
# 1400:	learn: 0.6521885	total: 16.9s	remaining: 1m 43s
# 1500:	learn: 0.6506137	total: 18s	remaining: 1m 42s
# 1600:	learn: 0.6490533	total: 19.3s	remaining: 1m 41s
# 1700:	learn: 0.6475818	total: 20.4s	remaining: 1m 39s
# 1800:	learn: 0.6460296	total: 21.7s	remaining: 1m 38s
# 1900:	learn: 0.6446357	total: 22.8s	remaining: 1m 37s
# 2000:	learn: 0.6431583	total: 24.1s	remaining: 1m 36s
# 2100:	learn: 0.6417244	total: 25.2s	remaining: 1m 34s
# 2200:	learn: 0.6402595	total: 26.6s	remaining: 1m 34s
# 2300:	learn: 0.6388388	total: 27.7s	remaining: 1m 32s
# 2400:	learn: 0.6373824	total: 29s	remaining: 1m 31s
# 2500:	learn: 0.6358586	total: 30.1s	remaining: 1m 30s
# 2600:	learn: 0.6342367	total: 31.4s	remaining: 1m 29s
# 2700:	learn: 0.6323784	total: 32.5s	remaining: 1m 27s
# 2800:	learn: 0.6307381	total: 33.9s	remaining: 1m 27s
# 2900:	learn: 0.6290769	total: 35s	remaining: 1m 25s
# 3000:	learn: 0.6271804	total: 36.3s	remaining: 1m 24s
# 3100:	learn: 0.6252505	total: 37.4s	remaining: 1m 23s
# 3200:	learn: 0.6232684	total: 39s	remaining: 1m 22s
# 3300:	learn: 0.6213109	total: 40.1s	remaining: 1m 21s
# 3400:	learn: 0.6192507	total: 41.4s	remaining: 1m 20s
# 3500:	learn: 0.6173707	total: 42.6s	remaining: 1m 19s
# 3600:	learn: 0.6153958	total: 43.9s	remaining: 1m 18s
# 3700:	learn: 0.6134408	total: 45s	remaining: 1m 16s
# 3800:	learn: 0.6115548	total: 46.4s	remaining: 1m 15s
# 3900:	learn: 0.6096054	total: 47.6s	remaining: 1m 14s
# 4000:	learn: 0.6076724	total: 48.9s	remaining: 1m 13s
# 4100:	learn: 0.6058140	total: 50s	remaining: 1m 11s
# 4200:	learn: 0.6038545	total: 51.3s	remaining: 1m 10s
# 4300:	learn: 0.6019358	total: 52.4s	remaining: 1m 9s
# 4400:	learn: 0.6002175	total: 53.7s	remaining: 1m 8s
# 4500:	learn: 0.5984448	total: 54.9s	remaining: 1m 7s
# 4600:	learn: 0.5966841	total: 56.2s	remaining: 1m 5s
# 4700:	learn: 0.5947580	total: 57.4s	remaining: 1m 4s
# 4800:	learn: 0.5930305	total: 58.7s	remaining: 1m 3s
# 4900:	learn: 0.5912105	total: 59.8s	remaining: 1m 2s
# 5000:	learn: 0.5894727	total: 1m 1s	remaining: 1m 1s
# 5100:	learn: 0.5877922	total: 1m 2s	remaining: 59.8s
# 5200:	learn: 0.5860751	total: 1m 3s	remaining: 58.7s
# 5300:	learn: 0.5843665	total: 1m 4s	remaining: 57.4s
# 5400:	learn: 0.5825103	total: 1m 6s	remaining: 56.3s
# 5500:	learn: 0.5807700	total: 1m 7s	remaining: 55s
# 5600:	learn: 0.5789895	total: 1m 8s	remaining: 53.8s
# 5700:	learn: 0.5773809	total: 1m 9s	remaining: 52.5s
# 5800:	learn: 0.5757620	total: 1m 11s	remaining: 51.4s
# 5900:	learn: 0.5741587	total: 1m 12s	remaining: 50.1s
# 6000:	learn: 0.5725178	total: 1m 13s	remaining: 49s
# 6100:	learn: 0.5709335	total: 1m 14s	remaining: 47.7s
# 6200:	learn: 0.5692981	total: 1m 16s	remaining: 46.6s
# 6300:	learn: 0.5676444	total: 1m 17s	remaining: 45.3s
# 6400:	learn: 0.5659810	total: 1m 18s	remaining: 44.1s
# 6500:	learn: 0.5643729	total: 1m 19s	remaining: 42.9s
# 6600:	learn: 0.5627261	total: 1m 20s	remaining: 41.7s
# 6700:	learn: 0.5611567	total: 1m 22s	remaining: 40.4s
# 6800:	learn: 0.5596476	total: 1m 23s	remaining: 39.2s
# 6900:	learn: 0.5579612	total: 1m 24s	remaining: 38s
# 7000:	learn: 0.5563567	total: 1m 25s	remaining: 36.8s
# 7100:	learn: 0.5546913	total: 1m 27s	remaining: 35.5s
# 7200:	learn: 0.5530575	total: 1m 28s	remaining: 34.4s
# 7300:	learn: 0.5515396	total: 1m 29s	remaining: 33.1s
# 7400:	learn: 0.5499608	total: 1m 30s	remaining: 31.9s
# 7500:	learn: 0.5484157	total: 1m 32s	remaining: 30.7s
# 7600:	learn: 0.5468838	total: 1m 33s	remaining: 29.5s
# 7700:	learn: 0.5453889	total: 1m 34s	remaining: 28.2s
# 7800:	learn: 0.5437900	total: 1m 35s	remaining: 27s
# 7900:	learn: 0.5422655	total: 1m 36s	remaining: 25.7s
# 8000:	learn: 0.5406405	total: 1m 38s	remaining: 24.5s
# 8100:	learn: 0.5391824	total: 1m 39s	remaining: 23.3s
# 8200:	learn: 0.5376441	total: 1m 40s	remaining: 22.1s
# 8300:	learn: 0.5361946	total: 1m 41s	remaining: 20.8s
# 8400:	learn: 0.5347917	total: 1m 43s	remaining: 19.6s
# 8500:	learn: 0.5333610	total: 1m 44s	remaining: 18.4s
# 8600:	learn: 0.5318672	total: 1m 45s	remaining: 17.2s
# 8700:	learn: 0.5302599	total: 1m 46s	remaining: 15.9s
# 8800:	learn: 0.5289066	total: 1m 48s	remaining: 14.7s
# 8900:	learn: 0.5275483	total: 1m 49s	remaining: 13.5s
# 9000:	learn: 0.5260221	total: 1m 50s	remaining: 12.3s
# 9100:	learn: 0.5246184	total: 1m 51s	remaining: 11s
# 9200:	learn: 0.5231654	total: 1m 53s	remaining: 9.82s
# 9300:	learn: 0.5217326	total: 1m 54s	remaining: 8.58s
# 9400:	learn: 0.5202127	total: 1m 55s	remaining: 7.36s
# 9500:	learn: 0.5189667	total: 1m 56s	remaining: 6.13s
# 9600:	learn: 0.5174785	total: 1m 58s	remaining: 4.91s
# 9700:	learn: 0.5160683	total: 1m 59s	remaining: 3.67s
# 9800:	learn: 0.5147715	total: 2m	remaining: 2.45s
# 9900:	learn: 0.5134667	total: 2m 1s	remaining: 1.22s
# 9999:	learn: 0.5120561	total: 2m 2s	remaining: 0us
# Precision: 0.55990099009901
# Recall: 0.7368078175895766

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.34      0.41      1340
#            1       0.56      0.74      0.64      1535
#
#     accuracy                           0.55      2875
#    macro avg       0.54      0.54      0.52      2875
# weighted avg       0.54      0.55      0.53      2875

# %%
catboost_cl_top_50_importance = plot_feature_importance(catboost_cl_top_100, X_train_100)
